# %%
## The system calls are only needed if the script fails because modules are not found. 
# If used, change paths to your installation path
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET-main')


# %load_ext autoreload
# %autoreload 2
from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py

# %% [markdown]
# mport warnings<br>
# arnings.filterwarnings('ignore')

# %%
an = driver.analysis()
an.control = 'control_camx_mopitt.yaml'
an.read_control()
an.control_dict
# Out:
# {'analysis': {'start_time': '2022-07-20-00:00:00',
#   'end_time': '2022-07-21-00:59:00',
#   'output_dir': '../../../finalSIP_ouptut',
#   'debug': False,
#   'pairing_kwargs': {'sat_grid_clm': {'apply_ak': True,
#     'mod_to_overpass': True}},
#   'save': {'paired': {'method': 'netcdf', 'prefix': 'SIP', 'data': 'all'}},
#   'read': {'paired': {'method': 'netcdf',
#     'filenames': {'mopitt_camx': ['SIP_mopitt_camx.nc4']}}}},
#  'model': {'camx': {'files': '/glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc',
#    'files_vert': '/glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/camx.3d.4km_lonlatcorrected.20220720.nc',
#    'mod_type': 'camx',
#    'is_global': False,
#    'mapping': {'mopitt': {'CO': 'column'}},
#    'plot_kwargs': {'color': 'red', 'marker': '^', 'linestyle': 'dotted'}}},
#  'obs': {'mopitt': {'filename': '../../../MOPITT/MOP03J-20220720-L3V5.9.3.he5',
#    'obs_type': 'sat_grid_clm',
#    'sat_type': 'mopitt_l3',
#    'variables': {'column': {'ylabel_plot': '$10^{18} molec/cm^{2}$',
#      'vmin_plot': 0.0,
#      'vmax_plot': 16}}}},
#  'plots': {'plot_ts': {'type': 'timeseries',
#    'fig_kwargs': {'figsize': [12, 6]},
#    'default_plot_kwargs': {'linewidth': 2.0, 'markersize': 10.0},
#    'text_kwargs': {'fontsize': 18.0},
#    'domain_type': ['all'],
#    'domain_name': ['Colorado'],
#    'data': ['mopitt_camx'],
#    'data_proc': {'rem_obs_nan': True,
#     'ts_select_time': 'time',
#     'ts_avg_window': 'D',
#     'set_axis': True}},
#   'plot_grp1': {'type': 'gridded_spatial_bias',
#    'fig_kwargs': {'states': True,
#     'figsize': [10, 5],
#     'extent': [-110, -101, 36, 42],
#     'counties': True,
#     'markersize': 500},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['custom:box'],
#    'domain_name': ['Colorado'],
#    'domain_info': {'Colorado': {'bounds': [-110, -101, 36, 42]}},
#    'data': ['mopitt_camx'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': True}}}}

# %%
an.open_models()
an.models
# Out:
# camx
# /glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# {'camx': model(
#      model='camx',
#      is_global=False,
#      radius_of_influence=1000000.0,
#      mod_kwargs={'var_list': ['CO'], 'surf_only': False, 'fname_met_3D': '/glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/camx.3d.4km_lonlatcorrected.20220720.nc', 'fname_met_2D': None},
#      file_str='/glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc',
#      label='camx',
#      obj=...,
#      mapping={'mopitt': {'CO': 'column'}},
#      variable_dict=None,
#      label='camx',
#      ...
#  )}

# %%
an.open_obs()
an.obs
# Out:
# Reading MOPITT
# ../../../MOPITT/MOP03J-20220720-L3V5.9.3.he5
# {'mopitt': observation(
#      obs='mopitt',
#      label='mopitt',
#      file='../../../MOPITT/MOP03J-20220720-L3V5.9.3.he5',
#      obj=...,
#      type='pt_src',
#      sat_type='mopitt_l3',
#      sat_method=None,
#      data_proc=None,
#      variable_dict={'column': {'ylabel_plot': '$10^{18} molec/cm^{2}$', 'vmin_plot': 0.0, 'vmax_plot': 16}},
#      resample=None,
#      time_var=None,
#      regrid_method=None,
#  )}

# %%
an.pair_data()

# output paired data
an.save_analysis()
# Out:
# 1, in pair data
# sampling model to 10:30 local overpass time
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET-main/melodies_monet/util/satellite_utilities.py:60: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   local_utc_offset = (modobj['longitude']/15).round().astype('timedelta64[h]')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# Writing: ../../../finalSIP_ouptut/SIP_mopitt_camx.nc4

# %%
# Currently there is a bug in the code when generating the legend for the timeseries plot and also only a limited number of plots is available. 
# MELODIES MONET is being updated to use xarray for all plotting which then will enable to plot timeseries, absolute and bias maps and Taylor diagrams for all satellite data.  

an.plotting()
# Out:
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'mopitt', 'ylim': [0.0, 16.0], 'fontsize': 14.4}
# -0.8300017666816711 0.8300017666816711

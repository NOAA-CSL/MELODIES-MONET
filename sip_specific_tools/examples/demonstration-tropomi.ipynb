# %% [markdown]
# # Compare CAMx to TROPOMI NO2, HCHO or CO

# %%
# The sys calls are only needed if the script fails because of modules not found 
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET/')

# %%
from melodies_monet import driver
import melodies_monet as mm
import monetio as mio
import monet
from melodies_monet import driver
import numpy as np

# %%
# READ THE control yaml file
import xarray as xr
an = driver.analysis()
an.control = 'control_camx_tropomiAK_no2.yaml'
#an.control = 'control_camx_tropomiAK_hcho.yaml'
#an.control = 'control_camx_tropomiAK_co.yaml'
an.read_control()

# %%
# Read observations and models, pair data and generate paired output file
# or just read a paired outputfile if already exists
an.open_obs()
an.open_models()
an.pair_data()
an.save_analysis()
#an.read_analysis()

# %%
# plotting and statistics
an.plotting()
an.stats()

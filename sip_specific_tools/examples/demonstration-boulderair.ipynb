# %% [markdown]
# # Using MELODIES-MONET for SIP evaluation - BoulderAir surface measurements

# %%
## The system calls are only needed if the script fails because modules are not found. 
# If used, change paths to your installation path
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET-main')

# %load_ext autoreload
# %autoreload 2
from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py

# %%
from melodies_monet import driver

an = driver.analysis()
an.control = 'control_camx_boulderair.yaml'
an.read_control()
an.open_models()
an.open_obs()
an.pair_data()
an.save_analysis()
an.read_analysis()
an.plotting()
an.stats()
# Out:
# camx
# /glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 1, in pair data
# After pairing:                      time siteid  longitude  latitude  elevation  benzene  \
# 0    2022-06-30 10:00:00    BSE  -105.0364   39.9844     1607.0    0.024
# 1    2022-06-30 10:00:00    LUR  -105.0477   40.1762     1514.0    0.065
# 2    2022-06-30 10:00:00    ECC  -105.0519   40.0402     1538.0    0.049
# 3    2022-06-30 11:00:00    BSE  -105.0364   39.9844     1607.0    0.027
# 4    2022-06-30 11:00:00    LUR  -105.0477   40.1762     1514.0    0.053
# ...                  ...    ...        ...       ...        ...      ...
# 2299 2022-08-01 08:00:00    LUR  -105.0477   40.1762     1514.0    0.125
# 2300 2022-08-01 08:00:00    ECC  -105.0519   40.0402     1538.0    0.151
# 2301 2022-08-01 09:00:00    BSE  -105.0364   39.9844     1607.0    0.027
# 2302 2022-08-01 09:00:00    LUR  -105.0477   40.1762     1514.0    0.086
# 2303 2022-08-01 09:00:00    ECC  -105.0519   40.0402     1538.0    0.154
#
#       toluene  ethane  propane  BENZ  TOL
# 0       0.145   4.209    1.630   NaN  NaN
# 1       0.181  16.650    9.353   NaN  NaN
# 2       0.142   3.774    1.219   NaN  NaN
# 3       0.106   2.370    1.166   NaN  NaN
# 4       0.187   3.471    2.139   NaN  NaN
# ...       ...     ...      ...   ...  ...
# 2299    0.370   3.108    1.603   NaN  NaN
# 2300    0.431   6.161    3.246   NaN  NaN
# 2301    0.128   2.786    1.185   NaN  NaN
# 2302    0.254   4.881    2.678   NaN  NaN
# 2303    0.586   7.062    3.428   NaN  NaN
#
# [2304 rows x 11 columns]
# saving pair
# Writing: ../../../finalSIP_ouptut/boulderair_CAMX.nc4
# Reading: ../../../finalSIP_ouptut/boulderair_CAMX.nc4
# Warning: ty_scale not specified for benzene, so default used.
# Reference std: 0.032144250704910796
# Warning: ty_scale not specified for toluene, so default used.
# Reference std: 0.10644531420684286
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.

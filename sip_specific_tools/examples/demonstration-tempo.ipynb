# %% [markdown]
# # Compare CAMx to TEMPO NO2, HCHO and FNR (HCHO/NO2)

# %%
# The system calls are only needed if the script fails because modules are not found. 
# If used, change paths to your installation path
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET-main')


# %load_ext autoreload
# %autoreload 2
from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
import numpy as np
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py

# %%
# READ THE control yaml file
import xarray as xr
an = driver.analysis()
an.control = 'control_camx_tempo.yaml'
an.read_control()

# %%
# Read observations and models, pair data and generate paired output file
# or just read a paired outputfile if already exists
an.open_obs()
an.open_models()
#this line is only needed to adjust the CAMx date from 2022 to 2024 since no TEMPO data are available for 2022
an.models["CAMX"].obj["time"] = an.models["CAMX"].obj["time"]  + np.timedelta64(731, "D")
an.pair_data()
an.save_analysis()
#an.read_analysis()
# Out:
# Reading TEMPO L2
# /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720*_S00*
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T102926Z_S001G01.nc
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/sat/tempo_l2.py:66: UserWarning: Calculating pressure in TEMPO data requires surface_pressure. Adding surface_pressure to output variables
#   warnings.warn(
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T103606Z_S001G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T104243Z_S001G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T104921Z_S001G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T105558Z_S001G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T110235Z_S001G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T110931Z_S002G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T111611Z_S002G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T112248Z_S002G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T112926Z_S002G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T113603Z_S002G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T114240Z_S002G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T114936Z_S003G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T115616Z_S003G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T120253Z_S003G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T120931Z_S003G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T121608Z_S003G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T122245Z_S003G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T122941Z_S004G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T123621Z_S004G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T124258Z_S004G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T124936Z_S004G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T125613Z_S004G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T130250Z_S004G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T130946Z_S005G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T131626Z_S005G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T132303Z_S005G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T132941Z_S005G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T133618Z_S005G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T134255Z_S005G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T134951Z_S006G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T135631Z_S006G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T140311Z_S006G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T140949Z_S006G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T141626Z_S006G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T142303Z_S006G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T142941Z_S006G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T143618Z_S006G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T144255Z_S006G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T144952Z_S007G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T145629Z_S007G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T150306Z_S007G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T150944Z_S007G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T151618Z_S007G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T152252Z_S007G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T152927Z_S007G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T153601Z_S007G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T174216Z_S008G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T174554Z_S008G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T174951Z_S009G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T175631Z_S009G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T180311Z_S009G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T180949Z_S009G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T181626Z_S009G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T182303Z_S009G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T182941Z_S009G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T183618Z_S009G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240720T184255Z_S009G09.nc
# Reading TEMPO L2
# /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720*_S0*
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T000248Z_S016G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T000944Z_S017G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T001624Z_S017G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T002301Z_S017G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T002939Z_S017G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T003616Z_S017G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T004253Z_S017G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T004949Z_S018G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T005629Z_S018G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T010306Z_S018G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T010944Z_S018G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T011621Z_S018G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T012258Z_S018G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T102926Z_S001G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T103606Z_S001G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T104243Z_S001G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T104921Z_S001G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T105558Z_S001G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720T110235Z_S001G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240720
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET-main/melodies_monet/util/sat_l2_swath_utility_tempo.py:616: UserWarning: 2024-07-20T18:42:55Z granule domain has no overlap with model. Discarding.
#   warnings.warn(f"{ref_time} granule domain has no overlap with model. Discarding.")
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/xesmf/backend.py:41: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# Writing: ../../../finalSIP_ouptut/2024-07-20_tempo_l2_no2_CAMX.nc4
# Writing: ../../../finalSIP_ouptut/2024-07-20_tempo_l2_hcho_CAMX.nc4

# %%
# calculate FNR from NO2 and HCHO paired output and generate FNR paired output file
# only calculate FNR for pixels with NO2 > 1e15 molec/cm2
an.obs["tempo_l2_FNR"] = driver.observation()
an.obs["tempo_l2_FNR"].sat_type = "tempo_l2"
an.obs["tempo_l2_FNR"].variable_dict = {"tempo_l2_FNR": {"ylabel_plot": "FNR"}}

models = ["CAMX"]
no2 = ["NO2"]
hcho = ["FORM"]

for pair in an.paired.keys():
    an.paired[pair].obj = an.paired[pair].obj.sel(time=(an.paired[pair].obj['time'].dt.hour > 4))

for no2_m, hcho_m, model in zip(no2, hcho, models):
    ratio_FNR = xr.Dataset()
    ratio_FNR["tempo_l2_FNR"] = (
        an.paired[f"tempo_l2_hcho_{model}"].obj["vertical_column"]
        / an.paired[f"tempo_l2_no2_{model}"].obj["vertical_column_troposphere"]
    ).where(an.paired[f"tempo_l2_no2_{model}"].obj["vertical_column_troposphere"] > 1e15)
    ratio_FNR[f"{model}_FNR"] = (
        an.paired[f"tempo_l2_hcho_{model}"].obj[hcho_m]
        / an.paired[f"tempo_l2_no2_{model}"].obj[no2_m]
    ).where(an.paired[f"tempo_l2_no2_{model}"].obj[no2_m] > 1e15)   

    p = driver.pair()
    p.type = "sat_swath_clm"
    p.obs = "tempo_l2_FNR"
    p.model = f"{model}"
    p.model_vars = [f"{model}_FNR"]
    p.obs_vars = ["tempo_l2_FNR"]
    p.obj = ratio_FNR
    p.filename = f"tempo_l2_FNR_{model}.nc"
    an.paired[f"tempo_l2_FNR_{model}"] = p

# %%
# plotting and statistics
an.plotting()
an.stats()
# Out:
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'tempo_l2_no2', 'fontsize': 14.4}
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'tempo_l2_hcho', 'fontsize': 14.4}
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 0.0 1e+16
# 0.0 1e+16
# 0.0 1e+16
# 0.0 1e+16
# Warning: ty_scale not specified for vertical_column_troposphere, so default used.
# Base standard deviation:  9.7e+14
# Reference std: 1
# Warning: ty_scale not specified for vertical_column, so default used.
# Base standard deviation:  3.72e+15
# Reference std: 1

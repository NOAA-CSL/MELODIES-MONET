# %%
# Compare CAMx to NOAA GML surface ozone

# %%
# The system calls are only needed if the script fails because modules are not found. 
# If used, change paths to your installation path
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET-main')


# %load_ext autoreload
# %autoreload 2
from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py

# %%
an = driver.analysis()
an.control = 'control_camx_noaa-gml.yaml'
an.read_control()
an.open_models()
an.open_obs()
# Out:
# camx
# /glade/campaign/acom/acom-da/Denver2024-SIP/Denver_O3_2023/camx/outputs/runS20_2016/camxv72_cb6r5.201606*.runS20.avrg.grd03.nc
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %%
an.pair_data()
# Out:
# 1, in pair data
# After pairing:           O3_obs siteid                time  latitude  longitude  O3
# 0     45.590000    nwr 2016-01-01 01:00:00   40.0531  -105.5864 NaN
# 1     47.200001    nwr 2016-01-01 02:00:00   40.0531  -105.5864 NaN
# 2     48.040001    nwr 2016-01-01 03:00:00   40.0531  -105.5864 NaN
# 3     47.430000    nwr 2016-01-01 04:00:00   40.0531  -105.5864 NaN
# 4     47.639999    nwr 2016-01-01 05:00:00   40.0531  -105.5864 NaN
# ...         ...    ...                 ...       ...        ...  ..
# 7037  53.599998    nwr 2016-12-31 19:00:00   40.0531  -105.5864 NaN
# 7038  54.529999    nwr 2016-12-31 20:00:00   40.0531  -105.5864 NaN
# 7039  60.720001    nwr 2016-12-31 21:00:00   40.0531  -105.5864 NaN
# 7040  57.380001    nwr 2016-12-31 22:00:00   40.0531  -105.5864 NaN
# 7041  53.110001    nwr 2016-12-31 23:00:00   40.0531  -105.5864 NaN
#
# [7042 rows x 6 columns]

# %%
an.save_analysis()
# Out:
# Writing: ../../../finalSIP_ouptut/NWR_noaa_gml_CAMx.nc4

# %%
an.read_analysis()
# Out:
# Reading: ../../../finalSIP_ouptut/NWR_noaa_gml_CAMx.nc4

# %%
an.plotting()
# Out:
# Warning: ty_scale not specified for O3_obs, so default used.
# Reference std: 11.682003
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.

# %%
an.stats()

# %%
import os
import sys
sys.path.append('../../')
from melodies_monet import driver
import numpy as np

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point

# %%
an = driver.analysis()
an.control = '../yaml/control_tropomi_l2_no2_ak.yaml'
an.read_control()

# %%
# --- satobs
an.open_obs()
# Out:
# Reading TROPOMI L2 with averaging kernel application
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T014024_20230627T032154_29548_03_020500_20230628T172501.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T032154_20230627T050324_29549_03_020500_20230628T192005.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T050324_20230627T064453_29550_03_020500_20230628T211310.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T064453_20230627T082623_29551_03_020500_20230628T224738.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T082623_20230627T100753_29552_03_020500_20230629T002254.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T100753_20230627T114923_29553_03_020500_20230629T022607.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T114923_20230627T133052_29554_03_020500_20230629T040256.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T133052_20230627T151222_29555_03_020500_20230629T053015.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T151222_20230627T165352_29556_03_020500_20230629T070113.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T165352_20230627T183521_29557_03_020500_20230629T090102.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T183521_20230627T201651_29558_03_020500_20230629T104156.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T201651_20230627T215821_29559_03_020500_20230629T122904.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T215821_20230627T233951_29560_03_020500_20230629T141501.nc
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230627T233951_20230628T012120_29561_03_020500_20230629T154136.nc

# %%
# --- model
an.open_models()
# Out:
# ufs
# /scratch3/BMC/rcm2/mbruckner/modeloutput/ufschem/comrot/aeromma_1x1/gfs.2023062[6-8]/00/model_data/atmos/history/gfs.t00z.atmf*.nc
# **** Reading UFS-AQM or UFS-Chem model output...

# %%
# --- paring
an.pair_data()
# Out:
# 1, in pair data

# %%
# output statistics
#an.stats()

# %%
# plotting based on the paired data
#from melodies_monet import driver
an.plotting()

# %%
import os
import sys
sys.path.append('../../')
from melodies_monet import driver
import numpy as np

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point

# %%
an = driver.analysis()
an.control = '../yaml/control_tropomi_l2_no2_ak.yaml'
an.read_control()
# Out:
# {'analysis': {'start_time': '2023-06-28',
#   'end_time': '2023-06-29',
#   'debug': True,
#   'output_dir': '/scratch4/BMC/rcm1/mbruckner/tropomi/',
#   'save': {'paired': {'method': 'netcdf', 'prefix': 'mm_test', 'data': 'all'}},
#   'read': {'paired': {'method': 'netcdf',
#     'filenames': {'tropomi_l2_no2_ufsaqm': ['mm_test_tropomi_l2_no2_ufsaqm.nc4']}}}},
#  'obs': {'tropomi_l2_no2': {'debug': True,
#    'filename': '/scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T*nc',
#    'obs_type': 'sat_swath_clm',
#    'sat_type': 'tropomi_l2_no2',
#    'variables': {'qa_value': {'quality_flag_min': 0.7,
#      'var_applied': ['nitrogendioxide_tropospheric_column'],
#      'fillvalue': 9.96921e+36},
#     'nitrogendioxide_tropospheric_column': {'scale': 6.022141e+19,
#      'fillvalue': 9.96921e+36,
#      'ylabel_plot': 'NO2 trop. columns',
#      'vmin_plot': 0.0,
#      'vmax_plot': 1e+16,
#      'nlevels_plot': 23,
#      'regulatory': False},
#     'averaging_kernel': {'fillvalue': 9.96921e+36},
#     'air_mass_factor_total': {'fillvalue': 9.96921e+36},
#     'air_mass_factor_troposphere': {'fillvalue': 9.96921e+36},
#     'latitude': 'None',
#     'longitude': 'None',
#     'preslev': {'tm5_constant_a': {'group': ['PRODUCT'], 'maximum': 9e+36},
#      'tm5_constant_b': {'group': ['PRODUCT'], 'maximum': 9e+36},
#      'surface_pressure': {'group': ['PRODUCT/SUPPORT_DATA/INPUT_DATA/'],
#       'maximum': 9e+36},
#      'tm5_tropopause_layer_index': {'group': ['PRODUCT']}}}}},
#  'model': {'ufsaqm': {'files': '/scratch3/BMC/rcm2/rhs/monet_example/AEROMMA/UFS-AQM/cmaq54_OriRave1/aqm.2023*/12/aqm.t12z.dyn.*.nc',
#    'mod_type': 'ufs',
#    'is_global': False,
#    'mod_to_overpass': True,
#    'mapping': {'tropomi_l2_no2': {'no2_ave': 'nitrogendioxide_tropospheric_column'}},
#    'projection': None,
#    'plot_kwargs': {'color': 'dodgerblue', 'marker': '^', 'linestyle': ':'}}},
#  'plots': {'plot_grp1': {'type': 'timeseries',
#    'fig_kwargs': {'figsize': [12, 6]},
#    'default_plot_kwargs': {'linewidth': 2.0, 'markersize': 10.0},
#    'text_kwargs': {'fontsize': 18.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['tropomi_l2_no2_ufsaqm'],
#    'data_proc': {'rem_obs_nan': True,
#     'ts_select_time': 'time',
#     'ts_avg_window': 'H',
#     'set_axis': False}},
#   'plot_grp2': {'type': 'gridded_spatial_bias',
#    'fig_kwargs': {'states': True, 'figsize': [10, 5]},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['tropomi_l2_no2_ufsaqm'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': True}},
#   'plot_grp3': {'type': 'taylor',
#    'fig_kwargs': {'figsize': [8, 8]},
#    'default_plot_kwargs': {'markersize': 10.0},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['tropomi_l2_no2_ufsqam'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': False}},
#   'plot_grp4': {'type': 'boxplot',
#    'fig_kwargs': {'figsize': [8, 6]},
#    'default_plot_kwargs': {'markersize': 10.0},
#    'text_kwargs': {'fontsize': 20.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['tropomi_l2_no2_ufsaqm'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': True}}},
#  'stats': {'stat_list': ['MB', 'NMB', 'R2', 'RMSE'],
#   'round_output': 2,
#   'output_table': True,
#   'output_table_kwargs': {'figsize': [12, 6],
#    'fontsize': 12.0,
#    'xscale': 1.4,
#    'yscale': 1.4,
#    'edges': 'horizontal'},
#   'domain_type': ['all'],
#   'domain_name': ['CONUS'],
#   'data': ['tropomi_l2_no2_ufsaqm']}}

# %%
# --- satobs
an.open_obs()
# Out:
# Reading TROPOMI L2 NO2
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T012120_20230628T030250_29562_03_020500_20230629T171250.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/MELODIES-MONET/examples/jupyter_notebooks/../../melodies_monet/driver/_observation.py:286: FutureWarning: read_trpdataset is an alias for open_dataset and may be removed in the future
#   self.obj = mio.sat._tropomi_l2_no2_mm.read_trpdataset(
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T030250_20230628T044420_29563_03_020500_20230629T185712.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T044420_20230628T062549_29564_03_020500_20230629T204646.nc
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T062549_20230628T080719_29565_03_020500_20230629T223040.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T080719_20230628T094849_29566_03_020500_20230630T000506.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T094849_20230628T113019_29567_03_020500_20230630T015842.nc
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T113019_20230628T131148_29568_03_020500_20230630T034659.nc
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T131148_20230628T145318_29569_03_020500_20230630T051457.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T145318_20230628T163448_29570_03_020500_20230630T064636.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T163448_20230628T181617_29571_03_020500_20230630T083753.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T181617_20230628T195747_29572_03_020500_20230630T102127.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T195747_20230628T213917_29573_03_020500_20230630T120227.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T213917_20230628T232047_29574_03_020500_20230630T135643.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column
# reading /scratch4/BMC/rcm1/mbruckner/tropomi/2023/NO2/S5P_OFFL_L2__NO2____20230628T232047_20230629T010216_29575_03_020500_20230630T152248.nc
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:48: UserWarning: Converting non-nanosecond precision timedelta values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   dtime = xr.DataArray(dtime_var[:].squeeze(), dims=("y",)).astype("timedelta64[ms]")
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# /scratch3/BMC/rcm2/mbruckner/melodies/monetio/monetio/sat/_tropomi_l2_no2_mm.py:60: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds["time"] = ((), ref_time_val, {"long_name": "reference time"})
# - qa_value
# - nitrogendioxide_tropospheric_column
# INFO:root:nitrogendioxide_tropospheric_column already masked
# - averaging_kernel
# INFO:root:averaging_kernel already masked
# - air_mass_factor_total
# INFO:root:air_mass_factor_total already masked
# - air_mass_factor_troposphere
# INFO:root:air_mass_factor_troposphere already masked
# - latitude
# - longitude
# - preslev
# INFO:root:tm5_tropopause_layer_index already masked
# INFO:root:surface_pressure already masked
# DEBUG:root:applying quality flag to nitrogendioxide_tropospheric_column

# %%
# --- model
an.open_models()
# Out:
# ufs
# /scratch3/BMC/rcm2/rhs/monet_example/AEROMMA/UFS-AQM/cmaq54_OriRave1/aqm.2023*/12/aqm.t12z.dyn.*.nc
# **** Reading UFS-AQM or UFS-Chem model output...

# %%
# --- paring
an.pair_data()
# Out:
# 1, in pair data
# sampling model to 13:30 local overpass time
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4172, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB 158.4 ... -25.74
#     lat                                  (y, x) float32 8MB -77.17 ... 51.22
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T0...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.17 ... 51.22
#     longitude                            (y, x) float32 8MB 158.4 ... -25.74
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 0
#  no2 satellite: -889150300000000.0 2263010000000000.0
# <xarray.Dataset> Size: 518MB
# Dimensions:                              (y: 3736, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 7MB 133.0 ... -52.94
#     lat                                  (y, x) float32 7MB -77.2 ... 69.98
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 30kB 2023-06-28T0...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 7MB 0.0 0.0 ... 0.07
#     nitrogendioxide_tropospheric_column  (y, x) float32 7MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 229MB nan ... 0.8455
#     air_mass_factor_total                (y, x) float32 7MB nan nan ... 10.61
#     air_mass_factor_troposphere          (y, x) float32 7MB nan nan ... 2.387
#     latitude                             (y, x) float32 7MB -77.2 ... 69.98
#     longitude                            (y, x) float32 7MB 133.0 ... -52.94
#     preslev                              (z, y, x) float32 229MB nan ... 9.304
#     troppres                             (y, x) float32 7MB nan ... 2.564e+04
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/melodies/MELODIES-MONET/examples/jupyter_notebooks/../../melodies_monet/util/sat_l2_swath_utility.py:88: RuntimeWarning: All-NaN axis encountered
#   print(' no2 satellite:', np.nanmin(no2_modgrid), np.nanmax(no2_modgrid))
# Done with TROPOMI regridding 2023-06-28 1
#  no2 satellite: nan nan
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4173, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB 107.6 ... -76.49
#     lat                                  (y, x) float32 8MB -77.21 ... 51.22
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T0...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.21 ... 51.22
#     longitude                            (y, x) float32 8MB 107.6 ... -76.49
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 2
#  no2 satellite: -1480618700000000.0 119109535000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4172, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB 82.27 ... -101.9
#     lat                                  (y, x) float32 8MB -77.19 ... 51.25
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T0...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.19 ... 51.25
#     longitude                            (y, x) float32 8MB 82.27 ... -101.9
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 3
#  no2 satellite: -3461100000000000.0 1322245400000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4173, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB 56.85 ... -127.2
#     lat                                  (y, x) float32 8MB -77.23 ... 51.24
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T0...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.23 ... 51.24
#     longitude                            (y, x) float32 8MB 56.85 ... -127.2
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 4
#  no2 satellite: -3228183000000000.0 445471000000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4172, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB 31.55 ... -152.6
#     lat                                  (y, x) float32 8MB -77.18 ... 51.23
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T1...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.18 ... 51.23
#     longitude                            (y, x) float32 8MB 31.55 ... -152.6
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 5
#  no2 satellite: -3569334500000000.0 2138713700000000.0
# <xarray.Dataset> Size: 579MB
# Dimensions:                              (y: 4174, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB 6.088 ... -178.0
#     lat                                  (y, x) float32 8MB -77.25 ... 51.2
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T1...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.25 ... 51.2
#     longitude                            (y, x) float32 8MB 6.088 ... -178.0
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 6
#  no2 satellite: -3557992500000000.0 1110473700000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4173, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -19.28 ... 156.6
#     lat                                  (y, x) float32 8MB -77.24 ... 51.25
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T1...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.24 ... 51.25
#     longitude                            (y, x) float32 8MB -19.28 ... 156.6
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 7
#  no2 satellite: -6840858000000000.0 3735186500000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4173, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -44.63 ... 131.3
#     lat                                  (y, x) float32 8MB -77.23 ... 51.23
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T1...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.23 ... 51.23
#     longitude                            (y, x) float32 8MB -44.63 ... 131.3
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 8
#  no2 satellite: -3838627000000000.0 6330591000000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4173, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -69.99 ... 105.9
#     lat                                  (y, x) float32 8MB -77.21 ... 51.22
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T1...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.21 ... 51.22
#     longitude                            (y, x) float32 8MB -69.99 ... 105.9
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 9
#  no2 satellite: -2291331800000000.0 2.263286e+16
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4172, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -95.39 ... 80.51
#     lat                                  (y, x) float32 8MB -77.22 ... 51.28
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T1...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.22 ... 51.28
#     longitude                            (y, x) float32 8MB -95.39 ... 80.51
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 10
#  no2 satellite: -6282598000000000.0 1.7895034e+16
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4172, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -120.8 ... 55.14
#     lat                                  (y, x) float32 8MB -77.24 ... 51.3
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T2...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.24 ... 51.3
#     longitude                            (y, x) float32 8MB -120.8 ... 55.14
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 11
#  no2 satellite: -4562964700000000.0 1.7597063e+16
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4172, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -146.2 ... 29.77
#     lat                                  (y, x) float32 8MB -77.23 ... 51.29
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T2...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.23 ... 51.29
#     longitude                            (y, x) float32 8MB -146.2 ... 29.77
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 12
#  no2 satellite: -1837062700000000.0 4509996400000000.0
# <xarray.Dataset> Size: 578MB
# Dimensions:                              (y: 4173, x: 450, z: 34)
# Coordinates:
#     lon                                  (y, x) float32 8MB -171.6 ... 4.392
#     lat                                  (y, x) float32 8MB -77.28 ... 51.29
#     time                                 datetime64[ns] 8B 2023-06-28
#     scan_time                            (y) datetime64[ns] 33kB 2023-06-28T2...
# Dimensions without coordinates: y, x, z
# Data variables:
#     qa_value                             (y, x) float32 8MB 0.0 0.0 ... 0.0 0.0
#     nitrogendioxide_tropospheric_column  (y, x) float32 8MB nan nan ... nan nan
#     averaging_kernel                     (y, x, z) float32 255MB nan nan ... nan
#     air_mass_factor_total                (y, x) float32 8MB nan nan ... nan nan
#     air_mass_factor_troposphere          (y, x) float32 8MB nan nan ... nan nan
#     latitude                             (y, x) float32 8MB -77.28 ... 51.29
#     longitude                            (y, x) float32 8MB -171.6 ... 4.392
#     preslev                              (z, y, x) float32 255MB nan nan ... nan
#     troppres                             (y, x) float32 8MB nan nan ... nan nan
# Attributes:
#     reference_time_string:  2023-06-28
#     quality_flag:           qa_value
#     quality_thresh_min:     0.7
#     var_applied:            ['nitrogendioxide_tropospheric_column']
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable nitrogendioxide_tropospheric_column as the horizontal dimensions for the regridding.
#   warnings.warn(
# /scratch3/BMC/rcm2/mbruckner/miniconda/envs/mm_develop/lib/python3.11/site-packages/xesmf/frontend.py:718: UserWarning: Using dimensions ('y', 'x') from data variable troppres as the horizontal dimensions for the regridding.
#   warnings.warn(
# Done with TROPOMI regridding 2023-06-28 13
#  no2 satellite: -1907595100000000.0 5674340600000000.0
# /scratch3/BMC/rcm2/mbruckner/melodies/MELODIES-MONET/examples/jupyter_notebooks/../../melodies_monet/util/sat_l2_swath_utility.py:91: RuntimeWarning: Mean of empty slice
#   no2_modgrid_avg['nitrogendioxide_tropospheric_column'][nd,:,:] = np.nanmean(np.where(no2_modgrid_all > 0.0, no2_modgrid_all, np.nan), axis=2)
# /scratch3/BMC/rcm2/mbruckner/melodies/MELODIES-MONET/examples/jupyter_notebooks/../../melodies_monet/util/sat_l2_swath_utility.py:93: RuntimeWarning: Mean of empty slice
#   tm5_tpause = np.nanmean(tropopause_intermediate,axis=2)

# %%
# output statistics
an.stats()

# %%
# plotting based on the paired data
#from melodies_monet import driver
an.plotting()
